# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# ### About:
#
# The data set is the full, cleaned results of the 2020 Stack Overflow Developer Survey.

# %%
#CSV file with main survey results, one respondent per row and one column per answer

df = pd.read_csv("~/downloads/developer_survey_2020/survey_results_public.csv")

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df.loc [:,['Age', 'CompTotal','WorkWeekHrs']]
# Out:
#         Age  CompTotal  WorkWeekHrs
# 0       NaN        NaN         50.0
# 1       NaN        NaN          NaN
# 2       NaN        NaN          NaN
# 3      25.0        NaN         40.0
# 4      31.0        NaN          NaN
# ...     ...        ...          ...
# 64456   NaN        NaN          NaN
# 64457   NaN        NaN          NaN
# 64458   NaN        NaN          NaN
# 64459   NaN        NaN          NaN
# 64460   NaN        NaN          NaN
#
# [64461 rows x 3 columns]

# %%
df.loc [10:15]
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 10          11                     I am a developer by profession      Yes
# 11          12                     I am a developer by profession       No
# 12          13  I am not primarily a developer, but I write co...      Yes
# 13          14                     I am a developer by profession      Yes
# 14          15             I am a student who is learning to code      Yes
# 15          16                     I am a developer by profession      Yes
#
#      Age Age1stCode CompFreq  CompTotal  ConvertedComp         Country  \
# 10  23.0         13   Yearly    31000.0        40070.0  United Kingdom
# 11  49.0         42  Monthly     1100.0        14268.0           Spain
# 12  53.0         14  Monthly     3000.0        38916.0     Netherlands
# 13  27.0         13   Yearly    66000.0        66000.0   United States
# 14   NaN         13      NaN        NaN            NaN          France
# ...

# %%
df.sort_values(by=['Age'], ascending=False)
# Out:
#        Respondent                      MainBranch Hobbyist    Age  \
# 14375       14419  I am a developer by profession      Yes  279.0
# 2625         2638  I am a developer by profession       No   99.0
# 5926         5950  I am a developer by profession      Yes   99.0
# 2510         2522  I am a developer by profession      Yes   99.0
# 45324       46268  I am a developer by profession      Yes   99.0
# ...           ...                             ...      ...    ...
# 64456       64858                             NaN      Yes    NaN
# 64457       64867                             NaN      Yes    NaN
# 64458       64898                             NaN      Yes    NaN
# 64459       64925                             NaN      Yes    NaN
# 64460       65112                             NaN      Yes    NaN
#
#           Age1stCode CompFreq     CompTotal  ConvertedComp        Country  \
# 14375             16   Yearly  4.900000e+04        52968.0    Netherlands
# ...

# %%
df['Country'].unique()
# Out:
# array(['Germany', 'United Kingdom', 'Russian Federation', 'Albania',
#        'United States', 'India', 'Tunisia', 'Spain', 'Netherlands',
#        'France', 'Belgium', 'Portugal', 'Canada', 'China', 'Ukraine',
#        'Italy', 'Brazil', 'Austria', 'Mexico', 'Sweden', 'Poland',
#        'Indonesia', 'Greece', 'Israel', 'Czech Republic',
#        'Bosnia and Herzegovina', 'Bulgaria', 'Serbia', 'Switzerland',
#        'Hungary', 'Nepal', 'Slovenia', 'Uruguay', 'Denmark', 'Pakistan',
#        'Taiwan', 'Romania', 'Finland', 'Costa Rica', 'Nigeria', 'Chile',
#        'Turkey', 'Panama', 'Ireland', 'Estonia', 'Philippines',
#        'Australia', 'Nomadic', 'Peru', 'Cyprus', 'Sri Lanka', 'Kenya',
#        'Norway', 'Kyrgyzstan', 'Iran', 'Croatia', 'Egypt', 'Argentina',
#        'Ghana', 'Latvia', 'Morocco', 'Bangladesh', 'Ecuador', 'Haiti',
#        'Venezuela, Bolivarian Republic of...', 'Colombia', 'Lithuania',
#        'El Salvador', 'Honduras', 'Ethiopia', 'Lebanon', 'Uganda',
# ...

# %%
df['DevType'].unique()
# Out:
# array(['Developer, desktop or enterprise applications;Developer, full-stack',
#        'Developer, full-stack;Developer, mobile', nan, ...,
#        'Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, front-end;System administrator',
#        'Academic researcher;Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Developer, QA or test;DevOps specialist;Senior executive/VP;System administrator',
#        'Data or business analyst;Developer, mobile;Senior executive/VP;System administrator'],
#       dtype=object)

# %%
df['DevType'].value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                  4424
# Developer, back-end                                                                                                                                                                                                                                                                                    3086
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                                                                                                                                         2227
# ...

# %%
4424/64461
# Out:
# 0.06863064488605514

# %%
df = df[df['DevType'].notna()]

# %%
df['DevType'].value_counts(normalize=True)
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                  0.089609
# Developer, back-end                                                                                                                                                                                                                                                                                    0.062508
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                                                                                                                                         0.045108
# ...

# %%
counts = df['DevType'].value_counts()
percent = df['DevType'].value_counts(normalize=True)
percent100 = df['DevType'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
#                                                     counts       per per100
# Developer, full-stack                                 4424  0.089609   9.0%
# Developer, back-end                                   3086  0.062508   6.3%
# Developer, back-end;Developer, front-end;Develo...    2227  0.045108   4.5%
# Developer, back-end;Developer, full-stack             1476  0.029897   3.0%
# Developer, front-end                                  1401  0.028378   2.8%
# ...                                                    ...       ...    ...
# Academic researcher;Data or business analyst;Da...       1  0.000020   0.0%
# Educator;Engineer, data;Engineering manager;Pro...       1  0.000020   0.0%
# Developer, desktop or enterprise applications;D...       1  0.000020   0.0%
# Developer, back-end;Developer, embedded applica...       1  0.000020   0.0%
# Database administrator;Designer;Developer, back...       1  0.000020   0.0%
#
# [8269 rows x 3 columns]

# %%
counts = df['Hobbyist'].value_counts()
percent = df['Hobbyist'].value_counts(normalize=True)
percent100 = df['Hobbyist'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
#      counts       per per100
# Yes   38078  0.771278  77.1%
# No    11292  0.228722  22.9%

# %%
counts = df['Hobbyist', 'Gender'== 'Man'].value_counts()
percent = df['Hobbyist', 'Gender'== 'Man'].value_counts(normalize=True)
percent100 = df['Hobbyist'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-48345950c160> in <module>
# ----> 1 counts = df['Hobbyist', 'Gender'==male].value_counts()
#       2 percent = df['Hobbyist'].value_counts(normalize=True)
#       3 percent100 = df['Hobbyist'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
#       4 pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
#
# NameError: name 'male' is not defined

# %%
newdf =  df.query('Gender == "Man" & Country=="United States"')

# %%
counts = newdf['Hobbyist'].value_counts()
percent = newdf['Hobbyist'].value_counts(normalize=True)
percent100 = newdf['Hobbyist'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
#      counts     per per100
# Yes    6407  0.7905  79.0%
# No     1698  0.2095  21.0%

# %%
newdf =  df.query('Country=="United States"')

# %%
newdf
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 7               8  I am a developer by profession      Yes  36.0         12
# 13             14  I am a developer by profession      Yes  27.0         13
# 16             17  I am a developer by profession      Yes  25.0         14
# 17             18  I am a developer by profession      Yes  32.0         12
# 18             19  I am a developer by profession       No  24.0         15
# ...           ...                             ...      ...   ...        ...
# 64385       53549                             NaN      Yes  26.0         21
# 64386       53697                             NaN      Yes  30.0         24
# 64413       58498                             NaN      Yes  32.0         23
# 64428       60931                             NaN      Yes   NaN         17
# 64456       64858                             NaN      Yes   NaN         16
#
# ...

# %%
counts = newdf['Hobbyist'].value_counts()
percent = newdf['Hobbyist'].value_counts(normalize=True)
percent100 = newdf['Hobbyist'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
#      counts     per per100
# Yes    6407  0.7905  79.0%
# No     1698  0.2095  21.0%

# %%
newdf['YearsCode'].value_counts()
# Out:
# 10                    601
# 20                    494
# 8                     402
# 7                     394
# 5                     386
# 6                     383
# 15                    374
# 12                    333
# 25                    316
# 9                     269
# 30                    247
# 4                     224
# 14                    224
# 16                    211
# 11                    207
# 13                    207
# 3                     202
# 18                    196
# 40                    176
# 22                    173
# 17                    171
# 35                    157
# 19                    133
# 23                    131
# 2                     123
# 21                    113
# 24                    106
# 38                     99
# 26                     96
# 37                     80
# 27                     71
# 34                     65
# 28                     65
# 32                     65
# 36                     61
# ...

# %%
newdf[newdf['YearsCode'] == '45']
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 1202         1207                     I am a developer by profession      Yes
# 1814         1823                     I am a developer by profession       No
# 1882         1891                     I am a developer by profession      Yes
# 3171         3185                     I am a developer by profession      Yes
# 3471         3485                     I am a developer by profession       No
# 4252         4268                     I am a developer by profession       No
# 4464         4480                     I am a developer by profession      Yes
# 4791         4807  I am not primarily a developer, but I write co...      Yes
# 5060         5079                     I am a developer by profession      Yes
# 6280         6306  I am not primarily a developer, but I write co...      Yes
# 6361         6388                     I am a developer by profession      Yes
# ...

# %%
counts = newdf['YearsCode'].value_counts()
percent = newdf['YearsCode'].value_counts(normalize=True)
percent100 = newdf['YearsCode'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
#                     counts       per per100
# 10                     601  0.074381   7.4%
# 20                     494  0.061139   6.1%
# 8                      402  0.049752   5.0%
# 7                      394  0.048762   4.9%
# 5                      386  0.047772   4.8%
# 6                      383  0.047401   4.7%
# 15                     374  0.046287   4.6%
# 12                     333  0.041213   4.1%
# 25                     316  0.039109   3.9%
# 9                      269  0.033292   3.3%
# 30                     247  0.030569   3.1%
# 4                      224  0.027723   2.8%
# 14                     224  0.027723   2.8%
# 16                     211  0.026114   2.6%
# 11                     207  0.025619   2.6%
# 13                     207  0.025619   2.6%
# 3                      202  0.025000   2.5%
# 18                     196  0.024257   2.4%
# 40                     176  0.021782   2.2%
# 22                     173  0.021411   2.1%
# ...

# %%
df.YearsCode.value_counts(normalize=True).mul(100).round(1).plot.hist(bins=11, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
counts = df['YearsCode'].value_counts() 
percent = df['YearsCode'].value_counts(normalize=True)
percent100 = df['YearsCode'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
#                     counts       per per100
# 10                    4111  0.083949   8.4%
# 5                     3145  0.064223   6.4%
# 6                     3026  0.061793   6.2%
# 8                     2943  0.060098   6.0%
# 7                     2897  0.059159   5.9%
# 15                    2483  0.050705   5.1%
# 20                    2473  0.050500   5.1%
# 12                    2283  0.046620   4.7%
# 4                     2232  0.045579   4.6%
# 9                     2062  0.042107   4.2%
# 3                     1828  0.037329   3.7%
# 11                    1539  0.031427   3.1%
# 14                    1415  0.028895   2.9%
# 13                    1387  0.028323   2.8%
# 25                    1296  0.026465   2.6%
# 16                    1149  0.023463   2.3%
# 2                     1077  0.021993   2.2%
# 30                    1066  0.021768   2.2%
# 18                    1057  0.021585   2.2%
# 17                    1026  0.020952   2.1%
# ...

# %%
df['OpSys'].unique()
# Out:
# array(['Windows', 'MacOS', 'Linux-based', nan, 'BSD'], dtype=object)

# %%
df = df[df['OpSys'].notna()]

# %%
df['OpSys'].unique()
# Out:
# array(['Windows', 'MacOS', 'Linux-based', 'BSD'], dtype=object)

# %%
counts = df['OpSys'].value_counts() 
percent = df['OpSys'].value_counts(normalize=True)
percent100 = df['OpSys'].value_counts(normalize=True).mul(100).astype(int)
df_s = pd.DataFrame({'os_type': df['OpSys'].unique(), 'per': percent, 'per100': percent100})

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Windows to BSD
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   os_type  4 non-null      object
#  1   per      4 non-null      float64
#  2   per100   4 non-null      int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 128.0+ bytes

# %%
df_s.plot(kind='barh',x='os_type',y='per100')
# Out:
# <AxesSubplot:ylabel='os_type'>

# %%
df['OpSys']
# Out:
# Index(['Windows', 'MacOS', 'Linux-based', 'BSD'], dtype='object')
